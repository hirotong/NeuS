# %%
import numpy as np
import os

# %%
data_path = "/home/hiro/dataset/NeuS/thin_catbus"

# %%
camera_file = np.load(os.path.join(data_path, "cameras_sphere.npz"))

# %%
print(dir(camera_file))
# Out:
# ['__abstractmethods__', '__class__', '__contains__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_files', 'allow_pickle', 'close', 'f', 'fid', 'files', 'get', 'items', 'iteritems', 'iterkeys', 'keys', 'pickle_kwargs', 'values', 'zip']

# %%
for k in camera_file.keys():
    print(k)
# Out:
# camera_mat_0
# camera_mat_inv_0
# world_mat_0
# world_mat_inv_0
# camera_mat_1
# camera_mat_inv_1
# world_mat_1
# world_mat_inv_1
# camera_mat_2
# camera_mat_inv_2
# world_mat_2
# world_mat_inv_2
# camera_mat_3
# camera_mat_inv_3
# world_mat_3
# world_mat_inv_3
# camera_mat_4
# camera_mat_inv_4
# world_mat_4
# world_mat_inv_4
# camera_mat_5
# camera_mat_inv_5
# world_mat_5
# world_mat_inv_5
# camera_mat_6
# camera_mat_inv_6
# world_mat_6
# world_mat_inv_6
# camera_mat_7
# camera_mat_inv_7
# world_mat_7
# world_mat_inv_7
# camera_mat_8
# camera_mat_inv_8
# world_mat_8
# world_mat_inv_8
# camera_mat_9
# camera_mat_inv_9
# world_mat_9
# world_mat_inv_9
# camera_mat_10
# camera_mat_inv_10
# world_mat_10
# world_mat_inv_10
# camera_mat_11
# camera_mat_inv_11
# world_mat_11
# world_mat_inv_11
# camera_mat_12
# camera_mat_inv_12
# world_mat_12
# world_mat_inv_12
# camera_mat_13
# camera_mat_inv_13
# world_mat_13
# world_mat_inv_13
# camera_mat_14
# camera_mat_inv_14
# world_mat_14
# ...
